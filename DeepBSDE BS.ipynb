# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks/DeepGA')

# !pip install munch
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (2.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from munch) (1.15.0)

# %%
import os
import time
import json
import munch
import logging

import numpy as np
import pandas as pd
import tensorflow as tf

import equation as eqn
from modelDeepBSDE import BSDESolver

# %%
start_time = time.time()

# The path to load json file
a = '/content/drive/MyDrive/Colab Notebooks/DeepGA/pricing_default_risk_d100.json'

with open(a) as json_data_file:
    config = json.load(json_data_file)
config = munch.munchify(config)
bsde = getattr(eqn, config.eqn_config.eqn_name)(config.eqn_config)
tf.keras.backend.set_floatx(config.net_config.dtype)

bsde_solver = BSDESolver(config, bsde)
training_history = bsde_solver.train()

elapsed_time = time.time() - start_time
print(elapsed_time)
# Out:
# step:     0,    loss: 1.2381e+03, Y0: 4.0519e+01,   elapsed time:   1
# step:   100,    loss: 1.1775e+03, Y0: 4.1316e+01,   elapsed time:  51
# step:   200,    loss: 1.1191e+03, Y0: 4.2102e+01,   elapsed time:  65
# step:   300,    loss: 1.0637e+03, Y0: 4.2880e+01,   elapsed time:  78
# step:   400,    loss: 1.0101e+03, Y0: 4.3650e+01,   elapsed time:  92
# step:   500,    loss: 9.5926e+02, Y0: 4.4407e+01,   elapsed time: 105
# step:   600,    loss: 9.0942e+02, Y0: 4.5156e+01,   elapsed time: 119
# step:   700,    loss: 8.6063e+02, Y0: 4.5896e+01,   elapsed time: 133
# step:   800,    loss: 8.1624e+02, Y0: 4.6619e+01,   elapsed time: 147
# step:   900,    loss: 7.7509e+02, Y0: 4.7319e+01,   elapsed time: 161
# step:  1000,    loss: 7.3703e+02, Y0: 4.7999e+01,   elapsed time: 174
# step:  1100,    loss: 7.0216e+02, Y0: 4.8659e+01,   elapsed time: 188
# step:  1200,    loss: 6.7010e+02, Y0: 4.9301e+01,   elapsed time: 201
# step:  1300,    loss: 6.4022e+02, Y0: 4.9933e+01,   elapsed time: 215
# step:  1400,    loss: 6.1173e+02, Y0: 5.0553e+01,   elapsed time: 228
# step:  1500,    loss: 5.8383e+02, Y0: 5.1172e+01,   elapsed time: 242
# step:  1600,    loss: 5.5702e+02, Y0: 5.1790e+01,   elapsed time: 255
# step:  1700,    loss: 5.3080e+02, Y0: 5.2407e+01,   elapsed time: 269
# step:  1800,    loss: 5.0557e+02, Y0: 5.3020e+01,   elapsed time: 283
# step:  1900,    loss: 4.8090e+02, Y0: 5.3632e+01,   elapsed time: 296
# step:  2000,    loss: 4.5747e+02, Y0: 5.4241e+01,   elapsed time: 309
# step:  2100,    loss: 4.3471e+02, Y0: 5.4848e+01,   elapsed time: 323
# step:  2200,    loss: 4.1232e+02, Y0: 5.5451e+01,   elapsed time: 337
# step:  2300,    loss: 3.9142e+02, Y0: 5.6051e+01,   elapsed time: 350
# step:  2400,    loss: 3.7128e+02, Y0: 5.6647e+01,   elapsed time: 364
# step:  2500,    loss: 3.5161e+02, Y0: 5.7238e+01,   elapsed time: 378
# step:  2600,    loss: 3.3265e+02, Y0: 5.7825e+01,   elapsed time: 391
# step:  6500,    loss: 1.3328e+01, Y0: 7.5663e+01,   elapsed time: 912
# step:  6600,    loss: 1.2853e+01, Y0: 7.5829e+01,   elapsed time: 926
# step:  6700,    loss: 1.2422e+01, Y0: 7.5993e+01,   elapsed time: 939
# step:  6800,    loss: 1.2056e+01, Y0: 7.6138e+01,   elapsed time: 953
# step:  6900,    loss: 1.1819e+01, Y0: 7.6274e+01,   elapsed time: 967
# step:  7000,    loss: 1.1645e+01, Y0: 7.6379e+01,   elapsed time: 980
# step:  7100,    loss: 1.1476e+01, Y0: 7.6485e+01,   elapsed time: 993
# step:  7200,    loss: 1.1371e+01, Y0: 7.6570e+01,   elapsed time: 1007
# step:  7300,    loss: 1.1301e+01, Y0: 7.6647e+01,   elapsed time: 1021
# step:  7400,    loss: 1.1242e+01, Y0: 7.6701e+01,   elapsed time: 1034
# step:  7500,    loss: 1.1204e+01, Y0: 7.6757e+01,   elapsed time: 1048
# step:  7600,    loss: 1.1146e+01, Y0: 7.6798e+01,   elapsed time: 1062
# step:  7700,    loss: 1.1121e+01, Y0: 7.6823e+01,   elapsed time: 1075
# step:  7800,    loss: 1.1068e+01, Y0: 7.6857e+01,   elapsed time: 1089
# step:  7900,    loss: 1.1122e+01, Y0: 7.6869e+01,   elapsed time: 1103
# step:  8000,    loss: 1.1163e+01, Y0: 7.6887e+01,   elapsed time: 1116
# step:  8100,    loss: 1.1069e+01, Y0: 7.6887e+01,   elapsed time: 1129
# step:  8200,    loss: 1.1057e+01, Y0: 7.6905e+01,   elapsed time: 1143
# step:  8300,    loss: 1.1059e+01, Y0: 7.6918e+01,   elapsed time: 1156
# step:  8400,    loss: 1.1025e+01, Y0: 7.6914e+01,   elapsed time: 1170
# step:  8500,    loss: 1.0962e+01, Y0: 7.6896e+01,   elapsed time: 1184
# step:  8600,    loss: 1.0987e+01, Y0: 7.6913e+01,   elapsed time: 1197
# step:  8700,    loss: 1.1014e+01, Y0: 7.6925e+01,   elapsed time: 1210
# step:  8800,    loss: 1.0973e+01, Y0: 7.6930e+01,   elapsed time: 1224
# step:  8900,    loss: 1.1012e+01, Y0: 7.6923e+01,   elapsed time: 1238
# step:  9000,    loss: 1.0982e+01, Y0: 7.6948e+01,   elapsed time: 1251
# step:  9100,    loss: 1.0949e+01, Y0: 7.6969e+01,   elapsed time: 1265
# step:  9200,    loss: 1.0883e+01, Y0: 7.6958e+01,   elapsed time: 1278
# step:  9300,    loss: 1.0928e+01, Y0: 7.6951e+01,   elapsed time: 1291
# step:  9400,    loss: 1.1010e+01, Y0: 7.6925e+01,   elapsed time: 1305
# step:  9500,    loss: 1.1044e+01, Y0: 7.6929e+01,   elapsed time: 1318
# step:  9600,    loss: 1.0991e+01, Y0: 7.6946e+01,   elapsed time: 1332
# step:  9700,    loss: 1.0984e+01, Y0: 7.6919e+01,   elapsed time: 1345
# step:  9800,    loss: 1.1002e+01, Y0: 7.6943e+01,   elapsed time: 1358
# step:  9900,    loss: 1.1021e+01, Y0: 7.6942e+01,   elapsed time: 1372
# step: 10000,    loss: 1.1095e+01, Y0: 7.6880e+01,   elapsed time: 1386
# 1386.9909660816193
